# %%
#Data 1.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('1.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [ 8 19 30 50 61 73 85 95]
# distance 3 idx: [ 2  8 11 19 24 27 30 35 42 46 50 54 61 66 69 73 76 80 85 88 95]

# %%
#Data 2.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('2.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [ 4 16 26 37 50 68 80 91]
# distance 3 idx: [ 4  7 11 16 21 26 30 35 43 46 50 59 62 68 71 75 80 84 88 91 96]

# %%
#Data 3.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('3.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [ 6 16 31 51 62 76 89]
# distance 3 idx: [ 6 11 16 22 25 28 31 35 38 43 48 51 54 59 62 68 72 76 80 86 89 93 97]

# %%
#Data 4.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('4.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [11 31 44 61 72 84 95]
# distance 3 idx: [ 7 11 23 31 35 44 50 54 61 64 72 84 89 95]

# %%
#Data 5.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('5.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [10 22 33 43 62 72 91]
# distance 3 idx: [ 3  7 10 16 22 28 33 36 43 49 62 72 76 81 85 91 95]

# %%
#Data 6.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('6.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [ 6 17 29 40 52 69 88]
# distance 3 idx: [ 2  6  9 14 17 22 25 29 32 36 40 43 46 52 55 58 61 66 69 75 81 88 93 97]

# %%
#Data 7.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('7.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [11 24 37 56 76 87 98]
# distance 3 idx: [ 2 11 16 24 27 33 37 45 56 59 70 76 87 91 98]

# %%
#Data 8.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('8.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [ 2 12 29 41 59 74 86 96]
# distance 3 idx: [ 2  8 12 17 20 26 29 33 38 41 47 53 56 59 62 68 74 77 81 86 92 96]

# %%
#Data 9.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('9.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [10 30 43 56 67 80 95]
# distance 3 idx: [ 3  6 10 15 18 23 30 37 43 46 49 56 63 67 71 75 80 87 92 95]

# %%
#Data 10.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('10.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [ 5 15 31 41 52 65 76 86 96]
# distance 3 idx: [ 5 10 15 28 31 34 41 48 52 57 62 65 70 73 76 79 82 86 92 96]

# %%
#Data 111.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('11.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [12 25 39 51 63 81 95]
# distance 3 idx: [ 3  7 12 17 25 32 39 42 51 54 60 63 67 71 75 81 88 95 98]

# %%
#Data 12.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('12.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [ 4 14 32 42 53 72 89]
# distance 3 idx: [ 4  8 14 23 32 38 42 50 53 62 66 72 79 82 89 98]

# %%
#Data 13.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('13.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [10 24 37 47 61 73 91]
# distance 3 idx: [ 3 10 14 21 24 29 37 47 57 61 69 73 79 83 91]

# %%
#Data 14.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('14.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [ 7 18 31 47 57 70 82 95]
# distance 3 idx: [ 3  7 11 15 18 26 31 35 39 42 47 51 57 61 65 70 75 78 82 90 95]

# %%
#Data 15.csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

#Mengambil data dari CSV
data = np.genfromtxt('15.csv', delimiter=',', usecols=(1, 2, 3, 4), dtype='int32')

#Mengambil subset data (1000-1100)
y = data[1000:1100, 1]

#Menemukan puncak dengan jarak tertentu
peaks_d10, _ = find_peaks(y, distance=10)
peaks_d3, _ = find_peaks(y, distance=3)

#Mencetak indeks puncak yang ditemukan
print('distance 10 idx:', peaks_d10)
print('distance 3 idx:', peaks_d3)

#Menampilkan grafik
plt.figure(figsize=(12, 5))
plt.plot(y, label='Data')
plt.plot(peaks_d3, y[peaks_d3], "vr", label='distance 3')
plt.plot(peaks_d10, y[peaks_d10], "xk", label='distance 10')
plt.legend()
plt.title('Puncak dengan Distance 3 dan 10')
plt.xlabel('Indeks')
plt.ylabel('Nilai')
plt.grid(True)
plt.show()
# Out:
# distance 10 idx: [ 5 24 35 50 69 80 92]
# distance 3 idx: [ 1  5  9 14 24 27 31 35 39 44 50 55 61 66 69 73 77 80 84 89 92 95]
